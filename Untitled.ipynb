# %%
import numpy as np
import pandas as pd

import IPython.display as ipd

import librosa
import librosa.display

import os
import matplotlib.pyplot as plt
import noisereduce as nr
import cv2

from skimage.io import imread
from skimage.transform import resize
# Out:
# c:\users\lauda\appdata\local\programs\python\python36\lib\site-packages\noisereduce\noisereduce.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# %matplotlib inline

# %%
for filename in os.listdir("podaci/golub"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/golub/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    mfccs = librosa.feature.mfcc(y=reduced_noise, sr=sr, n_mfcc=13)
    librosa.display.specshow(mfccs)
    fig.savefig("podaci/golubslikemfcc/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
for filename in os.listdir("podaci/vrana"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/vrana/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    mfccs = librosa.feature.mfcc(y=reduced_noise, sr=sr, n_mfcc=13)
    librosa.display.specshow(mfccs)
    fig.savefig("podaci/vranaslikemfcc/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
for filename in os.listdir("podaci/gavran"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/gavran/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    mfccs = librosa.feature.mfcc(y=reduced_noise, sr=sr, n_mfcc=13)
    librosa.display.specshow(mfccs)
    fig.savefig("podaci/gavranslikemfcc/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
for filename in os.listdir("podaci/sova"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/sova/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    mfccs = librosa.feature.mfcc(y=reduced_noise, sr=sr, n_mfcc=13)
    librosa.display.specshow(mfccs)

    fig.savefig("podaci/sovaslikemfcc/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
for filename in os.listdir("podaci/lasta"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/lasta/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    mfccs = librosa.feature.mfcc(y=reduced_noise, sr=sr, n_mfcc=13)
    librosa.display.specshow(mfccs)

    fig.savefig("podaci/lastaslikemfcc/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
for filename in os.listdir("podaci/vrabac"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/vrabac/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    mfccs = librosa.feature.mfcc(y=reduced_noise, sr=sr, n_mfcc=13)
    librosa.display.specshow(mfccs)

    fig.savefig("podaci/vrabacslikemfcc/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
# Out:
# c:\users\lauda\appdata\local\programs\python\python36\lib\site-packages\librosa\core\audio.py:146: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')

# %%
for filename in os.listdir("podaci/gavran"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/gavran/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaci/gavranslike/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaci/gavranslike/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaci/gavranslike/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaci/vrana"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/vrana/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaci/vranaslike/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaci/vranaslike/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaci/vranaslike/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaci/golub"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/golub/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaci/golubslike/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaci/golubslike/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaci/golubslike/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaci/sova"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/sova/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaci/sovaslike/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaci/sovaslike/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaci/sovaslike/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaci/lasta"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/lasta/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaci/lastaslike/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaci/lastaslike/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaci/lastaslike/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaci/vrabac"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaci/vrabac/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaci/vrabacslike/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaci/vrabacslike/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaci/vrabacslike/'+filename.split(".")[0]+'.png', image3Channel)

# %%
fig = plt.figure(1,frameon=False)
fig.set_size_inches(6,6)
filename = "untitled4.wav"
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)
y, sr = librosa.load("podaci/vrabac/"+filename)
reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

fig.savefig(filename.split(".")[0])

img = cv2.imread('untitled4.png') 
image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
img_dil = cv2.dilate(image_bin, kernel, iterations=2)
img_close = cv2.erode(img_dil, kernel, iterations=2)
image3Channel=np.stack((img_close,)*3, -1)
cv2.imwrite('untitled4.png', image3Channel)
# Out:
# True

# %%
for filename in os.listdir("podaciValidacija/gavran"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaciValidacija/gavran/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaciValidacija/gavranslikeValidacija/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaciValidacija/gavranslikeValidacija/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaciValidacija/gavranslikeValidacija/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaciValidacija/vrana"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaciValidacija/vrana/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaciValidacija/vranaslikeValidacija/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaciValidacija/vranaslikeValidacija/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaciValidacija/vranaslikeValidacija/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaciValidacija/golub"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaciValidacija/golub/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaciValidacija/golubslikeValidacija/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaciValidacija/golubslikeValidacija/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaciValidacija/golubslikeValidacija/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaciValidacija/sova"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaciValidacija/sova/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaciValidacija/sovaslikeValidacija/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaciValidacija/sovaslikeValidacija/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaciValidacija/sovaslikeValidacija/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaciValidacija/lasta"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaciValidacija/lasta/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaciValidacija/lastaslikeValidacija/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaciValidacija/lastaslikeValidacija/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaciValidacija/lastaslikeValidacija/'+filename.split(".")[0]+'.png', image3Channel)
for filename in os.listdir("podaciValidacija/vrabac"):
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    y, sr = librosa.load("podaciValidacija/vrabac/"+filename)
    reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
    s = librosa.feature.melspectrogram(y=reduced_noise, sr=sr, n_mels=128,fmax=10000)
    librosa.display.specshow(librosa.power_to_db(s**2,ref=np.max), fmax=10000) #power = S**2

    fig.savefig("podaciValidacija/vrabacslikeValidacija/"+filename.split(".")[0])
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')
    img = cv2.imread('podaciValidacija/vrabacslikeValidacija/'+filename.split(".")[0]+'.png') 
    image_bin = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    img_dil = cv2.dilate(image_bin, kernel, iterations=2)
    img_close = cv2.erode(img_dil, kernel, iterations=2)
    image3Channel=np.stack((img_close,)*3, -1)
    cv2.imwrite('podaciValidacija/vrabacslikeValidacija/'+filename.split(".")[0]+'.png', image3Channel)

# %%
y, sr = librosa.load("untitled4.wav")
reduced_noise = nr.reduce_noise(audio_clip=y, noise_clip=y, prop_decrease = 1, verbose=False)
librosa.output.write_wav("untitled4WithFilter.wav", reduced_noise, sr, norm=False)
